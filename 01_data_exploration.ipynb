# %% [markdown]
# # 📊 01 - Data Exploration
# Exploring Coca-Cola stock data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../data/KO_1919-09-06_2025-04-17.csv')
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)
df.head()
